# %% [markdown]
# ## A pipeline for Transcriptomic data using Seurat
# ### Sample F8_38

# %%
library(Seurat)
# Out:
# Error in library(Seurat): there is no package called ‘Seurat’
# Traceback:
#
# 1. library(Seurat)

# %%
if (FALSE) {
# For output from CellRanger < 3.0
data_dir <- '/home/kv64/Desktop/science_papers/spatial_ml_tumor/F8_38_c'
list.files(data_dir) # Should show barcodes.tsv, genes.tsv, and matrix.mtx
expression_matrix <- Read10X(data.dir = data_dir)
seurat_object = CreateSeuratObject(counts = expression_matrix)

# For output from CellRanger >= 3.0 with multiple data types
data_dir <- '/home/kv64/Desktop/science_papers/spatial_ml_tumor/F8_38_c'
list.files(data_dir) # Should show barcodes.tsv.gz, features.tsv.gz, and matrix.mtx.gz
data <- Read10X(data.dir = data_dir)
seurat_object = CreateSeuratObject(counts = data$`Gene Expression`)
seurat_object[['Protein']] = CreateAssayObject(counts = data$`Antibody Capture`)
}

# %% [markdown]
# ### 1. Read data to a Seurat object

# %%
library(dplyr)
library(Seurat)
library(patchwork)

# Load the PBMC dataset
pbmc.data <- Read10X(data.dir = "/home/kv64/Desktop/science_papers/spatial_ml_tumor/F8_38_c/outs/filtered_feature_bc_matrix")
# Initialize the Seurat object with the raw (non-normalized data).
pbmc <- CreateSeuratObject(counts = pbmc.data, project = "pbmc3k", min.cells = 3, min.features = 200)
pbmc
# Out:
# Warning message:
# “Feature names cannot have underscores ('_'), replacing with dashes ('-')”
# An object of class Seurat
# 34966 features across 3541 samples within 1 assay
# Active assay: RNA (34966 features, 0 variable features)

# %% [markdown]
# ### Standard pre-processing workflow

# %%
# pbmc[["percent.mt"]] <- PercentageFeatureSet(pbmc, pattern = "^MT-")

# %%
# # Visualize QC metrics as a violin plot
# VlnPlot(pbmc, features = c("nFeature_RNA", "nCount_RNA", "percent.mt"), ncol = 3)

# %%
# plot1 <- FeatureScatter(pbmc, feature1 = "nCount_RNA", feature2 = "percent.mt")
# plot2 <- FeatureScatter(pbmc, feature1 = "nCount_RNA", feature2 = "nFeature_RNA")
# plot1 + plot2

# %% [markdown]
# ### 2. Normalizing the data

# %%
pbmc <- NormalizeData(pbmc, normalization.method = "LogNormalize", scale.factor = 10000)

# %%
pbmc <- NormalizeData(pbmc)

# %% [markdown]
# ### 3. Identification of highly variable features (recommended Top 2000)

# %%
pbmc <- FindVariableFeatures(pbmc, selection.method = "vst", nfeatures = 2000)

# Identify the 10 most highly variable genes
top10 <- head(VariableFeatures(pbmc), 10)

# plot variable features with and without labels
plot1 <- VariableFeaturePlot(pbmc)
plot2 <- LabelPoints(plot = plot1, points = top10, repel = TRUE)
options(repr.plot.width=15, repr.plot.height=10)
plot1 + plot2
# Out:
# When using repel, set xnudge and ynudge to 0 for optimal results
# plot without title

# %% [markdown]
# ### 4. Scalind data center around zeros for all genes

# %%
# all.genes <- rownames(pbmc)
# pbmc <- ScaleData(pbmc, features = all.genes)

# %% [markdown]
# ### 5. Dimensionality reduction using PCA for all genes

# %%
# pbmc <- RunPCA(pbmc, features = VariableFeatures(object = pbmc))

# %% [markdown]
# ### 6. Scalind data center around zeros for top 2000 features

# %%
pbmc <- ScaleData(pbmc)
# Out:
# Centering and scaling data matrix

# %% [markdown]
# ### 7. Dimensionality Reduction using PCA for top 2000 features

# %%
pbmc <- RunPCA(pbmc, features = VariableFeatures(object = pbmc))
# Out:
# PC_ 1
# Positive:  GRCh38-LRRC75A, GRCm39-Col1a1, GRCm39-Col1a2, GRCm39-Col3a1, GRCh38-MT1X, GRCh38-IFI27, GRCh38-HSPA6, GRCh38-IFIT1, GRCh38-OAS2, GRCh38-CCL5
# 	   GRCh38-KRT81, GRCh38-ENSG00000276384, GRCh38-BTG2-DT, GRCh38-ENSG00000288764, GRCh38-S100A7, GRCm39-Gja5, GRCm39-Crispld2, GRCm39-Timp1, GRCm39-Acta1, GRCm39-Psca
# 	   GRCm39-Gpnmb, GRCm39-Trem2, GRCm39-Msln, GRCh38-FGG, GRCm39-Col6a1, GRCm39-Sprr1a, GRCm39-Myl7, GRCm39-Slfn4, GRCm39-C3ar1, GRCm39-Areg
# Negative:  GRCm39-Mup3, GRCm39-Wfdc21, GRCm39-Cdo1, GRCm39-Scd1, GRCm39-Orm1, GRCm39-Gnmt, GRCm39-Cyp2c70, GRCm39-Serpina1c, GRCm39-Apoh, GRCm39-Mgst1
# 	   GRCm39-Fgg, GRCm39-Apoc4, GRCm39-Azgp1, GRCm39-Apob, GRCm39-Car3, GRCm39-Apof, GRCm39-Akr1c6, GRCm39-C4bp, GRCm39-Serpina1b, GRCm39-Rnase4
# 	   GRCm39-Plg, GRCm39-Pcbd1, GRCm39-Serpina1a, GRCm39-Apoc1, GRCm39-Rgn, GRCm39-Hpd, GRCm39-Dbi, GRCm39-Apcs, GRCm39-Hamp, GRCm39-Rdh7
# PC_ 2
# Positive:  GRCm39-Upp2, GRCm39-Ces3b, GRCm39-Pck1, GRCm39-Inmt, GRCm39-Mup21, GRCm39-Cps1, GRCm39-Thrsp, GRCm39-Otc, GRCm39-Cyp8b1, GRCm39-Car3
# 	   GRCm39-Tat, GRCm39-Mup9, GRCm39-Ugt3a1, GRCm39-Cyp3a25, GRCm39-Slc10a1, GRCm39-BC024386, GRCm39-Agxt, GRCm39-Dpyd, GRCm39-Gls2, GRCm39-Ces1f
# 	   GRCm39-Cyp2f2, GRCm39-Sds, GRCm39-Haao, GRCm39-Cyp2c29, GRCm39-Ugt2a3, GRCm39-Nudt7, GRCm39-Cth, GRCm39-Sult2a8, GRCm39-Gm48633, GRCm39-Aass
# Negative:  GRCm39-Col1a2, GRCm39-Col3a1, GRCm39-Tmsb4x, GRCm39-Gpx3, GRCm39-Col1a1, GRCm39-Lyz2, GRCm39-Ifi27l2a, GRCm39-Vim, GRCm39-Col6a1, GRCm39-Lgals3
# 	   GRCm39-Col5a1, GRCm39-Fcer1g, GRCm39-Ctsb, GRCm39-Cd68, GRCm39-Psap, GRCm39-Gpnmb, GRCm39-Ctsd, GRCm39-Rps12, GRCm39-Rps24, GRCm39-Fau
# 	   GRCm39-Timp1, GRCm39-Rpl41, GRCm39-Cyba, GRCm39-Rplp1, GRCm39-Tyrobp, GRCm39-Rpl13, GRCm39-C1qb, GRCm39-Crip1, GRCm39-Rps15a, GRCm39-Rpl21
# PC_ 3
# Positive:  GRCm39-Hal, GRCm39-Sds, GRCm39-Cyp2f2, GRCm39-Lyz2, GRCm39-Upp2, GRCm39-Gls2, GRCm39-Cyp2a12, GRCm39-Aspg, GRCm39-Cyp8b1, GRCm39-Gm31583
# 	   GRCm39-Got1, GRCm39-Gpnmb, GRCm39-Hamp2, GRCm39-Tff3, GRCm39-1810008I18Rik, GRCm39-Trem2, GRCm39-Tyrobp, GRCm39-Mup21, GRCm39-Aldh1b1, GRCm39-Arg1
# 	   GRCm39-Fcer1g, GRCm39-Aass, GRCm39-Ces3b, GRCm39-Ccl9, GRCm39-Cnmd, GRCm39-Ces1e, GRCm39-C1qc, GRCm39-Slc3a1, GRCm39-Npc2, GRCm39-C1qa
# Negative:  GRCm39-Apoa4, GRCm39-Trf, GRCm39-Ahsg, GRCm39-Alb, GRCm39-Hp, GRCm39-Clu, GRCm39-Hpx, GRCm39-Apoc3, GRCm39-Rbp4, GRCm39-Apoa1
# 	   GRCm39-Apoa2, GRCm39-Krt18, GRCm39-Lcn2, GRCm39-Gc, GRCm39-Ttr, GRCm39-Krt8, GRCm39-Serpina7, GRCm39-Tgm2, GRCm39-Fabp1, GRCm39-C3
# 	   GRCm39-Igfbp1, GRCm39-Serpina3k, GRCm39-Fgb, GRCm39-Ambp, GRCm39-Gstm1, GRCm39-Bsg, GRCm39-Gulo, GRCm39-Gstm3, GRCm39-Vtn, GRCm39-Pzp
# PC_ 4
# Positive:  GRCm39-Cyp1a2, GRCm39-Slc1a2, GRCm39-Glul, GRCm39-Cyp2c50, GRCm39-Cyp2c39, GRCm39-Adgrv1, GRCm39-Cyp2c29, GRCm39-Cyp2c38, GRCm39-Cyp3a11, GRCm39-Cyp2c54
# 	   GRCm39-Lhpp, GRCm39-Cyp7b1, GRCm39-Wif1, GRCm39-Hsd3b5, GRCm39-Gstm2, GRCm39-Nxpe2, GRCm39-Oat, GRCm39-Slc22a1, GRCm39-Fitm1, GRCm39-Rdh9
# 	   GRCm39-Aldh3a2, GRCm39-Hba-a2, GRCm39-Cyp7a1, GRCm39-Pcp4l1, GRCm39-Slc13a3, GRCm39-Lect2, GRCm39-Gstm3, GRCm39-Sult2a8, GRCm39-Hbb-bt, GRCm39-Mup14
# Negative:  GRCm39-Sds, GRCm39-Cyp2f2, GRCm39-Aldh1b1, GRCm39-Cyp2a12, GRCm39-Hsd17b6, GRCm39-Spp1, GRCm39-Gls2, GRCm39-Hal, GRCm39-Hsd17b13, GRCm39-Aspg
# 	   GRCm39-Tff3, GRCm39-Slc3a1, GRCm39-Tstd1, GRCm39-Gldc, GRCm39-Etnppl, GRCm39-Arg1, GRCm39-Aqp8, GRCm39-Sfxn1, GRCm39-Uroc1, GRCm39-1810064F22Rik
# 	   GRCm39-Got1, GRCm39-Mt1, GRCm39-Tm4sf4, GRCm39-Pck1, GRCm39-Krt18, GRCm39-Gm32461, GRCm39-Cib3, GRCm39-Mt2, GRCm39-Crybb3, GRCm39-S100g
# PC_ 5
# Positive:  GRCm39-S100g, GRCm39-A2ml1, GRCm39-Esm1, GRCm39-Hspb1, GRCm39-Gm3776, GRCm39-Gsta1, GRCm39-Mt2, GRCm39-Serpina7, GRCm39-Gsta2, GRCm39-Bnip3
# 	   GRCm39-Ndrg1, GRCm39-Mt1, GRCm39-Nudt4, GRCm39-Gstp1, GRCm39-Depp1, GRCm39-Pgk1, GRCm39-Angptl3, GRCm39-Mif, GRCm39-Krt8, GRCm39-Tgm2
# 	   GRCm39-Gstp3, GRCm39-Pnrc1, GRCm39-Sat1, GRCm39-Npm1, GRCm39-Serpine1, GRCm39-Lipc, GRCm39-Tm4sf4, GRCm39-Krt18, GRCm39-Eif4ebp1, GRCm39-Slpi
# Negative:  GRCm39-Lyz2, GRCm39-Cxcl12, GRCm39-Col3a1, GRCm39-Col1a2, GRCm39-Apoe, GRCm39-Fabp1, GRCm39-Cd74, GRCm39-Ifi27l2a, GRCm39-C1qb, GRCm39-Tyrobp
# 	   GRCm39-Acaa1b, GRCm39-Reln, GRCm39-Aldob, GRCm39-Trem2, GRCm39-Ctsd, GRCm39-Apoa1, GRCm39-H2-Aa, GRCm39-C1qa, GRCm39-G6pc, GRCm39-Ucp2
# 	   GRCm39-Hmgcs2, GRCm39-Col1a1, GRCm39-Ctss, GRCm39-H2-Ab1, GRCm39-C3, GRCm39-H2-Q10, GRCm39-Rdh9, GRCm39-Hp, GRCm39-Pck1, GRCm39-Ly6e

# %%
VizDimLoadings(pbmc, dims = 1:2, reduction = "pca")
# Out:
# plot without title

# %% [markdown]
# ### Elbow Graph for selecting the optimum number of PCs
#
# The graph stabilizes after PC6. The first five PCs are sufficient to capture the variations.

# %%
ElbowPlot(pbmc)
# Out:
# plot without title

# %% [markdown]
# ### Heat Maps for PC

# %%
DimHeatmap(pbmc, dims = 1:2, cells = 500, balanced = TRUE)
# Out:
# Plot with title “PC_2”

# %%
DimHeatmap(pbmc, dims = 3:4, cells = 500, balanced = TRUE)
# Out:
# Plot with title “PC_4”

# %%
DimHeatmap(pbmc, dims = 5:6, cells = 500, balanced = TRUE)
# Out:
# Plot with title “PC_6”
